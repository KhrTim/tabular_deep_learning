# %%
import os
import json
import pandas as pd

# %%
# Path to the root directory containing the subdirectories with info.json
root_dir = 'data'

# List to hold all the info dictionaries
data = []

for subdir, dirs, files in os.walk(root_dir):
    for file in files:
        if file == 'info.json':
            file_path = os.path.join(subdir, file)
            with open(file_path, 'r') as f:
                info = json.load(f)
                entry = {
                    'name': subdir.split('/')[1],
                    'task_type': info.get('task_type'),
                    'n_num_features': info.get('n_num_features'),
                    'n_cat_features': info.get('n_cat_features'),
                    'tot_fea':info.get('n_num_features') + info.get('n_cat_features'),
                    'n_classes': info.get('n_classes'),
                    'train_size': info.get('train_size'),
                    'val_size': info.get('val_size'),
                    'test_size': info.get('test_size'),
                    'openml_id': info.get('openml_id'),
                    'location': subdir,
                    'source': info.get('source')
                }
                # Calculate total size
                entry['total_size'] = sum([
                    info.get('train_size', 0),
                    info.get('val_size', 0),
                    info.get('test_size', 0)
                ])
                data.append(entry)

# Create a DataFrame
df = pd.DataFrame(data)

# Display the dataframe
print(df)
# Out:
#                                                   name   task_type  \
# 0                                                 led7  multiclass
# 1                                       car-evaluation  multiclass
# 2                                 auction_verification  regression
# 3                                         ada_agnostic    binclass
# 4    GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_...    binclass
# ..                                                 ...         ...
# 296                                              heloc    binclass
# 297                                 KDDCup09_upselling    binclass
# 298                        Bank_Customer_Churn_Dataset    binclass
# 299                              FOREX_audcad-day-High    binclass
# 300        Firm-Teacher_Clave-Direction_Classification  multiclass
#
#      n_num_features  n_cat_features  tot_fea  n_classes  train_size  val_size  \
# 0                 0               7        7       10.0        2048       512
# 1                 0              21       21        4.0        1105       277
# 2                 6               1        7        NaN        1307       327
# 3                48               0       48        NaN        2919       730
# 4                 0              20       20        2.0        1024       256
# ..              ...             ...      ...        ...         ...       ...
# 296              22               0       22        2.0        6400      1600
# 297              34              15       49        2.0        3281       821
# 298               6               4       10        NaN        6400      1600
# 299              10               0       10        2.0        1173       294
# 300               0              16       16        NaN        6912      1728
#
#      test_size  openml_id                                           location  \
# 0          640    40678.0                                          data/led7
# 1          346    40664.0                                data/car-evaluation
# 2          409        NaN                          data/auction_verification
# 3          913        NaN                                  data/ada_agnostic
# 4          320    40649.0  data/GAMETES_Heterogeneity_20atts_1600_Het_0.4...
# ..         ...        ...                                                ...
# 296       2000    45023.0                                         data/heloc
# 297       1026    44186.0                            data/KDDCup09_upselling
# 298       2000        NaN                   data/Bank_Customer_Churn_Dataset
# 299        367    41721.0                         data/FOREX_audcad-day-High
# 300       2160        NaN   data/Firm-Teacher_Clave-Direction_Classification
#
#                                                 source  total_size
# 0    https://www.openml.org/search?type=data&status...        3200
# 1    https://www.openml.org/search?type=data&status...        1728
# 2    https://archive.ics.uci.edu/dataset/713/auctio...        2043
# 3    https://www.openml.org/search?type=data&status...        4562
# 4    https://www.openml.org/search?type=data&status...        1600
# ..                                                 ...         ...
# 296  https://www.openml.org/search?type=data&status...       10000
# 297  https://www.openml.org/search?type=data&status...        5128
# 298  https://www.kaggle.com/datasets/gauravtopre/ba...       10000
# 299  https://www.openml.org/search?type=data&status...        1834
# 300  https://archive.ics.uci.edu/dataset/324/firm+t...       10800
#
# [301 rows x 13 columns]

# %%
df.loc[df['location'].isin(['bank',
  "heloc",
  "Long",
  "adult",
  "rl",
  "Telecom_Churn_Dataset",
  "PizzaCutter3",
  "customer_satisfaction_in_airline",
  "dabetes_130-us_hospitals",
  "Cardiovascular-Disease-dataset",
  "mobile_c36_oversampling",
  "electricity",
  "FOREX_audsgd-hour-High",
  "Click_prediction_small"])][['location', 'task_type', 'n_num_features', 'total_size']].to_csv("experimental_ds.csv")

# %%
df.to_csv('dataset_info.csv')

# %%
task_type_dict = df.groupby('task_type')['location'].apply(list).to_dict()

# %%
task_type_dict
# Out:
# {'binclass': ['ada_agnostic',
#   'GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_50_EDM-2_001',
#   'Contaminant-detection-in-packaged-cocoa-hazelnut-spread-jars-using-Microwaves-Sensing-and-Machine-Learning-11.0GHz(Urbinati)',
#   'credit-g',
#   'pc3',
#   'ozone-level-8hr',
#   'ada',
#   'jasmine',
#   'water_quality',
#   'bank',
#   'Waterstress',
#   'spambase',
#   'online_shoppers',
#   'Wilt',
#   'jm1',
#   'Amazon_employee_access',
#   'kc1',
#   'seismic+bumps',
#   'naticusdroid+android+permissions+dataset',
#   'Fitness_Club_c',
#   'FOREX_audjpy-hour-High',
#   'company_bankruptcy_prediction',
#   'KDD',
#   'wine',
#   'PieChart3',
#   'delta_ailerons',
#   'htru',
#   'taiwanese_bankruptcy_prediction',
#   'law-school-admission-bianry',
#   'electricity',
#   'MIC',
#   'pc1',
#   'FOREX_audchf-day-High',
#   'Click_prediction_small',
#   'Contaminant-detection-in-packaged-cocoa-hazelnut-spread-jars-using-Microwaves-Sensing-and-Machine-Learning-10.5GHz(Urbinati)',
#   'Cardiovascular-Disease-dataset',
#   'Contaminant-detection-in-packaged-cocoa-hazelnut-spread-jars-using-Microwaves-Sensing-and-Machine-Learning-9.0GHz(Urbinati)',
#   'FICO-HELOC-cleaned',
#   'HR_Analytics_Job_Change_of_Data_Scientists',
#   'phoneme',
#   'Marketing_Campaign',
#   'twonorm',
#   'airlines_seed_0_nrows_2000_nclasses_10_ncols_100_stratify_True',
#   'customer_satisfaction_in_airline',
#   'statlog',
#   'Pumpkin_Seeds',
#   'GAMETES_Epistasis_2-Way_20atts_0.1H_EDM-1_1',
#   'default_of_credit_card_clients',
#   'eeg-eye-state',
#   'pc4',
#   'FOREX_audjpy-day-High',
#   'mozilla4',
#   'credit',
#   'eye_movements_bin',
#   'Basketball_c',
#   'madeline',
#   'VulNoneVul',
#   'mobile_c36_oversampling',
#   'ada_prior',
#   'rice_cammeo_and_osmancik',
#   'Performance-Prediction',
#   'Heart-Disease-Dataset-(Comprehensive)',
#   'sports_articles_for_objectivity_analysis',
#   'mammography',
#   'FOREX_cadjpy-day-High',
#   'house_16H',
#   'FOREX_audusd-hour-High',
#   'FOREX_audsgd-hour-High',
#   'BNG(breast-w)',
#   'shrutime',
#   'Pima_Indians_Diabetes_Database',
#   'Contaminant-detection-in-packaged-cocoa-hazelnut-spread-jars-using-Microwaves-Sensing-and-Machine-Learning-9.5GHz(Urbinati)',
#   'compass',
#   'pol',
#   'INNHotelsGroup',
#   'hill-valley',
#   'svmguide3',
#   'national-longitudinal-survey-binary',
#   'PhishingWebsites',
#   'kdd_ipums_la_97-small',
#   'QSAR_biodegradation',
#   'Water_Quality_and_Potability',
#   'California-Housing-Classification',
#   'National_Health_and_Nutrition_Health_Survey',
#   'Is-this-a-good-customer',
#   'FOREX_audcad-hour-High',
#   'in_vehicle_coupon_recommendation',
#   'dabetes_130-us_hospitals',
#   'kr-vs-kp',
#   'Contaminant-detection-in-packaged-cocoa-hazelnut-spread-jars-using-Microwaves-Sensing-and-Machine-Learning-10.0GHz(Urbinati)',
#   'Insurance',
#   'Intersectional-Bias-Assessment',
#   'ozone_level',
#   'BNG(tic-tac-toe)',
#   'adult',
#   'FOREX_cadjpy-hour-High',
#   'telco-customer-churn',
#   'churn',
#   'E-CommereShippingData',
#   'ringnorm',
#   'banknote_authentication',
#   'sylvine',
#   'rl',
#   'ibm-employee-performance',
#   'Diabetic_Retinopathy_Debrecen',
#   'MagicTelescope',
#   'Employee',
#   'dis',
#   'Telecom_Churn_Dataset',
#   'Long',
#   'shill-bidding',
#   'PizzaCutter3',
#   'Customer_Personality_Analysis',
#   'philippine',
#   'golf_play_dataset_extended',
#   'Shipping',
#   'heloc',
#   'KDDCup09_upselling',
#   'Bank_Customer_Churn_Dataset',
#   'FOREX_audcad-day-High'],
#  'multiclass': ['led7',
#   'car-evaluation',
#   'SDSS17',
#   'website_phishing',
#   'mfeat-factors',
#   'texture',
#   'semeion',
#   'JapaneseVowels',
#   'mfeat-karhunen',
#   'Credit_c',
#   'wall-robot-navigation',
#   'analcatdata_authorship',
#   'first-order-theorem-proving',
#   'connect-4',
#   'thyroid-dis',
#   'Gender_Gap_in_Spanish_WP',
#   'waveform_database_generator_version_1',
#   'satimage',
#   'baseball',
#   'mfeat-morphological',
#   'led24',
#   'drug_consumption',
#   'mice_protein_expression',
#   'BLE_RSSI_dataset_for_Indoor_localization',
#   'pendigits',
#   'eucalyptus',
#   'jungle_chess_2pcs_raw_endgame_complete',
#   'walking-activity',
#   'contraceptive_method_choice',
#   'allbp',
#   'cmc',
#   'dry_bean_dataset',
#   'eye_movements',
#   'allrep',
#   'page-blocks',
#   'Rain_in_Australia',
#   'one-hundred-plants-texture',
#   'steel_plates_faults',
#   'autoUniv-au7-1100',
#   'predict_students_dropout_and_academic_success',
#   'splice',
#   'mfeat-fourier',
#   'dna',
#   'okcupid_stem',
#   'shuttle',
#   'internet_firewall',
#   'turiye_student_evaluation',
#   'autoUniv-au4-2500',
#   'artificial-characters',
#   'mfeat-zernike',
#   'UJI_Pen_Characters',
#   'abalone',
#   'mfeat-pixel',
#   'one-hundred-plants-margin',
#   'wine-quality-white',
#   'kropt',
#   'microaggregation2',
#   'ASP-POTASSCO-classification',
#   'thyroid',
#   'segment',
#   'letter',
#   'gas-drift',
#   'BNG(cmc)',
#   'accelerometer',
#   'Indian_pines',
#   'yeast',
#   'one-hundred-plants-shape',
#   'internet_usage',
#   'Mobile_Price_Classification',
#   'GesturePhaseSegmentationProcessed',
#   'thyroid-ann',
#   'maternal_health_risk',
#   'optdigits',
#   'estimation_of_obesity_levels',
#   'kr-vs-k',
#   'vehicle',
#   'waveform-5000',
#   'helena',
#   'wine-quality-red',
#   'Firm-Teacher_Clave-Direction_Classification'],
#  'regression': ['auction_verification',
#   'qsar_fish_toxicity',
#   'house_prices_nominal',
#   'Parkinsons_Telemonitoring',
#   'Bias_correction_r_2',
#   'sensory',
#   'fifa',
#   'archive2',
#   'house_8L',
#   'bank8FM',
#   'cpu_act',
#   'Ailerons',
#   'IEEE80211aa-GATS',
#   'Large-scale_Wave_Energy_Farm_Sydney_49',
#   'elevators',
#   'us_crime',
#   'Bias_correction_r',
#   'CPS1988',
#   'Wine_Quality_white',
#   'Laptop_Prices_Dataset',
#   'NHANES_age_prediction',
#   'BNG(stock)',
#   'healthcare_insurance_expenses',
#   'Job_Profitability',
#   '3D_Estimation_using_RSSI_of_WLAN_dataset',
#   'Wine_Quality_red',
#   'BNG(lowbwt)',
#   'mv',
#   'steel_industry_energy_consumption',
#   'Goodreads-Computer-Books',
#   'satellite_image',
#   'dataset_sales',
#   'boston',
#   'BNG(mv)',
#   'house_16H_reg',
#   'CPMP-2015-regression',
#   'delta_elevators',
#   'colleges',
#   'gas_turbine_CO_and_NOx_emission',
#   'OnlineNewsPopularity',
#   'airfoil_self_noise',
#   'housing_price_prediction',
#   'stock_fardamento02',
#   'fried',
#   'socmob',
#   'qsar_aquatic_toxicity',
#   'stock',
#   'Physicochemical_r',
#   'garments_worker_productivity',
#   '2dplanes',
#   'weather_izmir',
#   'Parkinson_Multiple_Sound_Recording',
#   'Large-scale_Wave_Energy_Farm_Perth_100',
#   'puma32H',
#   'MIP-2016-regression',
#   'CookbookReviews',
#   'SAT11-HAND-runtime-regression',
#   'analcatdata_supreme',
#   'bank32nh',
#   'MiamiHousing2016',
#   'sulfur',
#   'Abalone_reg',
#   'Data_Science_Salaries',
#   'treasury',
#   'mauna-loa-atmospheric-co2',
#   'chscase_foot',
#   'pole',
#   'Diamonds',
#   '3D_Estimation_using_RSSI_of_WLAN_dataset_complete_1_target',
#   'yprop_4_1',
#   'Superconductivty',
#   'Kaggle_bike_sharing_demand_challange',
#   'Brazilian_houses_reproduced',
#   'Another-Dataset-on-used-Fiat-500-(1538-rows)',
#   'puma8NH',
#   'wine+quality',
#   'combined_cycle_power_plant',
#   'Facebook_Comment_Volume',
#   'kin8nm',
#   'Food_Delivery_Time',
#   'NASA_PHM2008',
#   'cpu_small',
#   'houses',
#   'wind',
#   'Shop_Customer_Data',
#   'concrete_compressive_strength',
#   'archive_r56_Portuguese',
#   'volume',
#   'Mobile_Phone_Market_in_Ghana',
#   'BNG(echoMonths)',
#   'communities_and_crime',
#   'Large-scale_Wave_Energy_Farm_Sydney_100',
#   'space_ga',
#   'house_sales_reduced',
#   'debutanizer',
#   'Moneyball',
#   'topo_2_1',
#   'avocado_sales',
#   '1000-Cameras-Dataset',
#   'pol_reg']}
